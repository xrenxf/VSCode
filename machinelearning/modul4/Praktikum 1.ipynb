# %% [markdown]
# # Load Data dan Preprocessing

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Input, Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU, Dropout

# %%
url = "https://drive.google.com/uc?id=18IBXOeb0O7TxDQhk2JsexHrdL0bgNZTn"
df = pd.read_csv(url, delimiter=';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %% [markdown]
# ## Preprocessing

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
label_encoder = LabelEncoder()
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      8       261         1     -1         0         3  0
# 1        5      8       151         1     -1         0         3  0
# 2        5      8        76         1     -1         0         3  0
# 3        5      8        92         1     -1         0         3  0
# 4        5      8       198         1     -1         0         3  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17      9       977         3     -1         0         3  1
# 45207   17      9       456         2     -1         0         3  1
# 45208   17      9      1127         5    184         3         2  1
# 45209   17      9       508         4     -1         0         3  0
# 45210   17      9       361         2    188        11         1  0
#
# [45211 rows x 17 columns]

# %%
numerical_cols = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

scaler = MinMaxScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

df
# Out:
#             age  job  marital  education  default   balance  housing  loan  \
# 0      0.519481    4        1          2        0  0.092259        1     0
# 1      0.337662    9        2          1        0  0.073067        1     0
# 2      0.194805    2        1          1        0  0.072822        1     1
# 3      0.376623    1        1          3        0  0.086476        1     0
# 4      0.194805   11        2          3        0  0.072812        0     0
# ...         ...  ...      ...        ...      ...       ...      ...   ...
# 45206  0.428571    9        1          2        0  0.080293        0     0
# 45207  0.688312    5        0          0        0  0.088501        0     0
# 45208  0.701299    5        1          1        0  0.124689        0     0
# 45209  0.506494    1        1          1        0  0.078868        0     0
# 45210  0.246753    2        1          1        0  0.099777        0     0
#
#        contact       day  month  duration  campaign     pdays  previous  \
# 0            2  0.133333      8  0.053070  0.000000  0.000000  0.000000
# 1            2  0.133333      8  0.030704  0.000000  0.000000  0.000000
# 2            2  0.133333      8  0.015453  0.000000  0.000000  0.000000
# 3            2  0.133333      8  0.018707  0.000000  0.000000  0.000000
# 4            2  0.133333      8  0.040260  0.000000  0.000000  0.000000
# ...        ...       ...    ...       ...       ...       ...       ...
# 45206        0  0.533333      9  0.198658  0.032258  0.000000  0.000000
# 45207        0  0.533333      9  0.092721  0.016129  0.000000  0.000000
# 45208        0  0.533333      9  0.229158  0.064516  0.212156  0.010909
# 45209        1  0.533333      9  0.103294  0.048387  0.000000  0.000000
# 45210        0  0.533333      9  0.073404  0.016129  0.216743  0.040000
#
#        poutcome  y
# 0             3  0
# 1             3  0
# 2             3  0
# 3             3  0
# 4             3  0
# ...         ... ..
# 45206         3  1
# 45207         3  1
# 45208         2  1
# 45209         3  0
# 45210         1  0
#
# [45211 rows x 17 columns]

# %%
X = df.drop('y', axis=1)
y = df['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Augmentasi

# %%
# Augmentasi
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # Modeling

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_dim=X_train_resampled.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
history = model.fit(X_train_resampled, y_train_resampled, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6332 - loss: 0.6379 - val_accuracy: 0.5860 - val_loss: 0.6439
# Epoch 2/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6922 - loss: 0.5883 - val_accuracy: 0.8458 - val_loss: 0.3978
# Epoch 3/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7125 - loss: 0.5647 - val_accuracy: 0.6237 - val_loss: 0.6255
# Epoch 4/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7371 - loss: 0.5371 - val_accuracy: 0.6167 - val_loss: 0.6512
# Epoch 5/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7555 - loss: 0.5142 - val_accuracy: 0.5069 - val_loss: 0.8592
# Epoch 6/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.7684 - loss: 0.5011 - val_accuracy: 0.8770 - val_loss: 0.3026
# Epoch 7/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7759 - loss: 0.4832 - val_accuracy: 0.7647 - val_loss: 0.5068
# Epoch 8/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7941 - loss: 0.4591 - val_accuracy: 0.4094 - val_loss: 1.0503
# Epoch 9/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7969 - loss: 0.4500 - val_accuracy: 0.4937 - val_loss: 0.9533
# Epoch 10/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8022 - loss: 0.4408 - val_accuracy: 0.6514 - val_loss: 0.7158
# Epoch 11/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8086 - loss: 0.4280 - val_accuracy: 0.6831 - val_loss: 0.6503
# Epoch 12/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8107 - loss: 0.4213 - val_accuracy: 0.3108 - val_loss: 1.3833
# Epoch 13/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8129 - loss: 0.4226 - val_accuracy: 0.7788 - val_loss: 0.4736
# Epoch 14/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8183 - loss: 0.4115 - val_accuracy: 0.6988 - val_loss: 0.6055
# Epoch 15/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8255 - loss: 0.3996 - val_accuracy: 0.8643 - val_loss: 0.3072
# Epoch 16/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8272 - loss: 0.3947 - val_accuracy: 0.8803 - val_loss: 0.2829
# Epoch 17/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8279 - loss: 0.3933 - val_accuracy: 0.8238 - val_loss: 0.3915
# Epoch 18/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8312 - loss: 0.3898 - val_accuracy: 0.7821 - val_loss: 0.4532
# Epoch 19/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8334 - loss: 0.3847 - val_accuracy: 0.8607 - val_loss: 0.3103
# Epoch 20/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8333 - loss: 0.3862 - val_accuracy: 0.8847 - val_loss: 0.3229
# Epoch 21/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8342 - loss: 0.3861 - val_accuracy: 0.8423 - val_loss: 0.3476
# Epoch 22/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8395 - loss: 0.3756 - val_accuracy: 0.8365 - val_loss: 0.3576
# Epoch 23/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8398 - loss: 0.3728 - val_accuracy: 0.7446 - val_loss: 0.5321
# Epoch 24/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8428 - loss: 0.3682 - val_accuracy: 0.8343 - val_loss: 0.3543
# Epoch 25/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8417 - loss: 0.3692 - val_accuracy: 0.8385 - val_loss: 0.3529
# Epoch 26/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8374 - loss: 0.3746 - val_accuracy: 0.7981 - val_loss: 0.4227
# Epoch 27/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8443 - loss: 0.3625 - val_accuracy: 0.6943 - val_loss: 0.6067
# Epoch 28/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8461 - loss: 0.3632 - val_accuracy: 0.8568 - val_loss: 0.3122
# Epoch 29/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8445 - loss: 0.3649 - val_accuracy: 0.8534 - val_loss: 0.3241
# Epoch 30/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8443 - loss: 0.3656 - val_accuracy: 0.7748 - val_loss: 0.4636
# Epoch 31/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8451 - loss: 0.3633 - val_accuracy: 0.8070 - val_loss: 0.3999
# Epoch 32/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8503 - loss: 0.3565 - val_accuracy: 0.8172 - val_loss: 0.3759
# Epoch 33/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8473 - loss: 0.3581 - val_accuracy: 0.7863 - val_loss: 0.4378
# Epoch 34/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8468 - loss: 0.3570 - val_accuracy: 0.8776 - val_loss: 0.2939
# Epoch 35/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8493 - loss: 0.3570 - val_accuracy: 0.8316 - val_loss: 0.3539
# Epoch 36/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8494 - loss: 0.3593 - val_accuracy: 0.7786 - val_loss: 0.4592
# Epoch 37/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8473 - loss: 0.3582 - val_accuracy: 0.7151 - val_loss: 0.5655
# Epoch 38/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8489 - loss: 0.3528 - val_accuracy: 0.5666 - val_loss: 0.8464
# Epoch 39/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8483 - loss: 0.3530 - val_accuracy: 0.7226 - val_loss: 0.5488
# Epoch 40/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8492 - loss: 0.3510 - val_accuracy: 0.5787 - val_loss: 0.8011
# Epoch 41/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8512 - loss: 0.3520 - val_accuracy: 0.8747 - val_loss: 0.2945
# Epoch 42/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8542 - loss: 0.3442 - val_accuracy: 0.8407 - val_loss: 0.3426
# Epoch 43/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8540 - loss: 0.3489 - val_accuracy: 0.8253 - val_loss: 0.3743
# Epoch 44/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8556 - loss: 0.3454 - val_accuracy: 0.8803 - val_loss: 0.2745
# Epoch 45/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8550 - loss: 0.3473 - val_accuracy: 0.8740 - val_loss: 0.2870
# Epoch 46/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8530 - loss: 0.3460 - val_accuracy: 0.7959 - val_loss: 0.4252
# Epoch 47/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8529 - loss: 0.3451 - val_accuracy: 0.2083 - val_loss: 1.4882
# Epoch 48/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8516 - loss: 0.3483 - val_accuracy: 0.7150 - val_loss: 0.5900
# Epoch 49/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8572 - loss: 0.3406 - val_accuracy: 0.7658 - val_loss: 0.4876
# Epoch 50/50
# 1748/1748 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8532 - loss: 0.3435 - val_accuracy: 0.7743 - val_loss: 0.4652

# %% [markdown]
# # Evaluasi

# %%
# Plot Akurasi
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

#Plot Loss
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(classification_report(y_test, y_pred))
# Out:
# 424/424 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.86     11966
#            1       0.33      0.85      0.47      1598
#
#     accuracy                           0.77     13564
#    macro avg       0.65      0.81      0.66     13564
# weighted avg       0.90      0.77      0.81     13564

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 424/424 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7729 - loss: 0.4696
# Test accuracy: 0.7742553949356079
